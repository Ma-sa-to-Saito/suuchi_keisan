# %% [markdown]
# # 課題内容

# %% [markdown]
# ## No.2 二分法とニュートン法の収束性
#
# 代数方程式に関する次の課題に答えよ．(2004年度期末試験)
#
# 1.exp(−x)=x2を二分法およびニュートン法で解け.
#
# 2.n回目の値xnと小数点以下10桁まで求めた値xf=0.7034674225との差Δxnの絶対値(abs)のlogをnの関数としてプロットし，その収束性を比較せよ．また，そ   の傾きの違いを両解法の原理から説明せよ.
#
#   https://nbviewer.jupyter.org/github/daddygongon/jupyter_num_calc/blob/master/numerical_calc/fsolve.ipynb#%E4%BE%8B%E9%A1%8C:%E4%BA%8C%E5%88%86%E6%B3%95%E3%81%A8Newton%E6%B3%95%E3%81%AE%E5%8F%8E%E6%9D%9F%E6%80%A7

# %% [markdown]
# ## No.3 精度,誤差,有効数字
#
# 有効数字
#
# 1.大きな数どおしのわずかな差は，丸め誤差にとくに影響を受ける. 23.173-23.094 を有効数字がそれぞれ5桁，4桁，3桁，2桁で計算した結果を示せ. 同様     に，0.81321/(23.173-23.094) を有効数字がそれぞれ5桁，4桁，3桁，2桁で計算した結果を示せ.
#
# 2.10進数10桁および3桁の有効桁数をもった計算機になったつもりで，以下の条件で預金を求める計算をおこなえ．元本を10000万円とする.
#   利息0.3%とする.複利計算で10年でいくらになるか．
#
#     https://nbviewer.jupyter.org/github/daddygongon/jupyter_num_calc/blob/master/numerical_calc/la_fundamentals.ipynb#%E8%AA%B2%E9%A1%8C

# %% [markdown]
# ## No.4 固有値,行列式,固有ベクトルの方向(グラフ)
#
# 下の図は
#
# $$
# A
# =
# \begin{pmatrix}
# 6 & 2 \\
# 2 & 4
# \end{pmatrix}
# $$
#
# を用いて変換される像を表わしている．この絵をpythonで描画せよ．また，この行列の固有値，行列式が何処に対応するか説明せよ．また，固有ベクトルの方向を記せ．(2007年度期末試験改)
# ![la_fund_ex1.png](attachment:la_fund_ex1.png)
#
#   https://nbviewer.jupyter.org/github/daddygongon/jupyter_num_calc/blob/master/numerical_calc/la_fundamentals.ipynb#%E8%AA%B2%E9%A1%8C

# %% [markdown]
# ## No.5 上下三角行列,連立方程式の解,LU分解,ガウスザイデル法(ヤコビ法),逆行列の求め方

# %% [markdown]
# ## 1.行列AをLU分解
# 次の行列AをLU分解し，上・下三角行列を求めよ．さらに連立方程式の解を求めよ.
#
# $$
# \begin{pmatrix}
# x+4y+3z \\
# x-2y+z \\
# 2x-2y-z
# \end{pmatrix}
# =
# \begin{pmatrix}
# 11 \\
# 11 \\
# 11
# \end{pmatrix}
# $$
#
# ##  2.pivot付きのLU分解
#  次の連立方程式の拡大行列をLU分解せよ．
#  pivot操作が必要となる．
#  P.A = L.Uを確かめよ．
#
# $$
# \begin{pmatrix}
# 3w+2x+2y+z \\
# 3w+2x+3y+z \\
# w-2x-3y+z \\
# 5w+3x-2y+5z
# \end{pmatrix}
# =
# \begin{pmatrix}
# -6 \\
# 2 \\
# -9 \\
# 2
# \end{pmatrix}
# $$
#
# ## 3.Gauss-Seidel法
# Jacobi法のプログラムを参照してGauss-Seidel法のプログラムを作れ．
#
# A=np.array([[5,1,1,1],[1,3,1,1],[1,-2,-9,1],[1,3,-2,5]])
# b=np.array([-6,2,-7,3])
# n=4
# に対して計算を行い，Jacobi法と収束性を比べよ．
#
# 最初の数回はこんな感じ．
#
# [-1.2       1.066667  0.407407  0.362963]
# [-1.567407  0.932346  0.436763  0.528779]
# [-1.579578  0.871345  0.46739   0.580064]
# [-1.58376   0.845435  0.478382  0.600844]
# [-1.584932  0.835236  0.482827  0.608976]
#
#   https://nbviewer.jupyter.org/github/daddygongon/jupyter_num_calc/blob/master/numerical_calc/la_matrix_inverse.ipynb#%E8%AA%B2%E9%A1%8C

# %% [markdown]
# ## No.6 ページランク,固有値,対角化行列

# %% [markdown]
# 1.上記手順を参考にして，pythonでページランクを求めよ．
# 2.このような問題ではすべての固有値・固有ベクトルを求める必要はなく，最大の固有値を示す固有ベクトルを求めるだけでよい．初期ベクトルを適当に決めて，何度も推移確率行列を掛ける反復法でページランクを求めよ．
#
# https://nbviewer.jupyter.org/github/daddygongon/jupyter_num_calc/blob/master/numerical_calc/la_eigen_vectors.ipynb#%E8%AA%B2%E9%A1%8C

# %% [markdown]
# ## No.7　補間(ラグランジュ,逆行列),ニュートンの差分商補間,中点即,台形即,両対数・片対数プロット
#
# 1.補間法
# 次の4点
# maple
# x y
# 0 1
# 1 2
# 2 3
# 3 1
# を通る多項式を(a)ラグランジュ補間, (b)逆行列で求めよ．
#
#
# 2.ニュートンの差分商補間（リンク先）
#
#   3.数値積分(I)
# 次の関数
#
# $$
#     f(x) = \frac{4}{1+x^2}
# $$
#
# をx=0..1で数値積分する．
#
# Nを2,4,8,…256ととり，N個の等間隔な区間にわけて中点法と台形則で求めよ.
# 小数点以下10桁まで求めた値3.141592654との差をdXとする．dXと分割数Nとを両対数プロット(loglogplot)して比較せよ (2008年度期末試験）
#
# 4.中点則の結果を示した．課題では，台形則を加えて，両者を比較せよ.(リンク先)
#
# https://nbviewer.jupyter.org/github/daddygongon/jupyter_num_calc/blob/master/numerical_calc/interpolation_integral.ipynb#%E8%AA%B2%E9%A1%8C

# %% [markdown]
# ## No.8 線形最小二乗法(1次,2次方程式の近似),3次元グラフへの近似

# %% [markdown]
# 1.
# 1次元の線形最小二乗法
# 次の4点のデータを以下の式で近似せよ(2006年度期末試験)．$$y=a_0+a_1x+a_2x^2$$
#
# xdata = np.array([1,2,3,4])
# ydata = np.array([1,3,4,10])
#
#
#
# 2.2次元の最小二乗フィット
# 以下のデータを次の式で近似せよ$$
# f(x,y)=a_0+a_1x+a_2y+a_3xy
# $$
#
# x,  y,  z
# -1, -1,  2.00000
# -1,  0,  0.50000
# -1,  1, -1.00000
#  0, -1,  0.50000
#  0,  0,  1.00000
#  0,  1,  1.50000
#  1, -1, -1.00000
#  1,  0,  1.50000
#  1,  1,  4.00000
# 結果は以下の通り．鞍点になってます．
# ![least_square_fit_ex_ans_fig.jpg](attachment:least_square_fit_ex_ans_fig.jpg)

# %% [markdown]
# ## No.9 Gaussian(ガウシアン)のfit,fitting

# %% [markdown]
# ガウス関数（正規分布）へのフィッティング(リンク参照)
#   https://nbviewer.jupyter.org/github/daddygongon/jupyter_num_calc/blob/master/numerical_calc/non_linear_fit.ipynb#%E8%AA%B2%E9%A1%8C

# %% [markdown]
# ## No.10 合成波のFFT,周波数の強度
#
# 合成波のFFT
# 下の例に従って，sin(i/13)とsin(i/2)の合成波を作成し，FFTをかけた後，周波数での強度を表示せよ．合成波(2sin(i2)+sin(i/2))との違いをのべよ．
# ![FFTExplot2d1.png](attachment:FFTExplot2d1.png)
# ![FFTExplot2d2.png](attachment:FFTExplot2d2.png)
# ![FFTExplot2d3.png](attachment:FFTExplot2d3.png)
#
#   https://nbviewer.jupyter.org/github/daddygongon/jupyter_num_calc/blob/master/numerical_calc/fft.ipynb#%E8%AA%B2%E9%A1%8C%E3%81%A8%E8%A7%A3%E7%AD%94%E4%BE%8B

# %% [markdown]
# ## No.11 雨粒,大砲
#
# 1.雨粒
# 空気抵抗を受ける雨粒の速度の変化を自分の言葉で説明しなさい．
#
# 2.大砲
# free fallの初期設定を変えて，x=0から鉛直方向にv=9.8で投げ上げたボールの時間変化を示しなさい．
#
# https://nbviewer.jupyter.org/github/daddygongon/jupyter_num_calc/blob/master/numerical_calc/ode/python_ode.ipynb#%E8%AA%B2%E9%A1%8C
